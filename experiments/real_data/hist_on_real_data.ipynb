# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
res = pd.DataFrame(columns=["dataset", "SC", "method"])

# %%
res = res.append( {"dataset": "DBLP5", "SC": 0.131, "method": "SPOC"}, ignore_index=True)
res = res.append( {"dataset": "DBLP1", "SC": 0.268, "method": "SPOC"}, ignore_index=True)
res = res.append( {"dataset": "DBLP4", "SC": 0.333, "method": "SPOC"}, ignore_index=True)
res = res.append( {"dataset": "MAG2", "SC": 0.161, "method": "SPOC"}, ignore_index=True)
res = res.append( {"dataset": "MAG1", "SC": 0.035, "method": "SPOC"}, ignore_index=True)
res = res.append( {"dataset": "DBLP3", "SC": 0.286, "method": "SPOC"}, ignore_index=True)
res = res.append( {"dataset": "DBLP2", "SC": 0.166, "method": "SPOC"}, ignore_index=True)

res = res.append( {"dataset": "DBLP1", "SC": 0.31, "method": "GeoNMF"}, ignore_index=True)
res = res.append( {"dataset": "DBLP1", "SC": 0.225, "method": "OCCAM"}, ignore_index=True)
res = res.append( {"dataset": "DBLP1", "SC": 0.105, "method": "SAAC"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP1", "SC": 0.27, "method": "BSNMF"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP1", "SC": 0.085, "method": "SVI"}, ignore_index=True)

res = res.append( {"dataset": "DBLP2", "SC": 0.295, "method": "GeoNMF"}, ignore_index=True)
res = res.append( {"dataset": "DBLP2", "SC": 0.235, "method": "OCCAM"}, ignore_index=True)
res = res.append( {"dataset": "DBLP2", "SC": 0.12, "method": "SAAC"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP2", "SC": 0.065, "method": "SVI"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP2", "SC": 0.255, "method": "BSNMF"}, ignore_index=True)

res = res.append( {"dataset": "DBLP3", "SC": 0.26, "method": "GeoNMF"}, ignore_index=True)
res = res.append( {"dataset": "DBLP3", "SC": 0.14, "method": "OCCAM"}, ignore_index=True)
res = res.append( {"dataset": "DBLP3", "SC": 0.095, "method": "SAAC"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP3", "SC": 0.11, "method": "SVI"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP3", "SC": 0.19, "method": "BSNMF"}, ignore_index=True)

res = res.append( {"dataset": "DBLP4", "SC": 0.27, "method": "GeoNMF"}, ignore_index=True)
res = res.append( {"dataset": "DBLP4", "SC": 0.23, "method": "OCCAM"}, ignore_index=True)
res = res.append( {"dataset": "DBLP4", "SC": 0.035, "method": "SAAC"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP4", "SC": 0.02, "method": "SVI"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP4", "SC": 0.035, "method": "BSNMF"}, ignore_index=True)

res = res.append( {"dataset": "DBLP5", "SC": 0.205, "method": "GeoNMF"}, ignore_index=True)
res = res.append( {"dataset": "DBLP5", "SC": 0.105, "method": "OCCAM"}, ignore_index=True)
res = res.append( {"dataset": "DBLP5", "SC": 0.025, "method": "SAAC"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP5", "SC": 0.03, "method": "SVI"}, ignore_index=True)
# res = res.append( {"dataset": "DBLP5", "SC": 0.05, "method": "BSNMF"}, ignore_index=True)

res = res.append( {"dataset": "MAG1", "SC": 0.13, "method": "GeoNMF"}, ignore_index=True)
res = res.append( {"dataset": "MAG1", "SC": 0.0505, "method": "OCCAM"}, ignore_index=True)
res = res.append( {"dataset": "MAG1", "SC": 0.04, "method": "SAAC"}, ignore_index=True)
# res = res.append( {"dataset": "MAG1", "SC": 0.08, "method": "SVI"}, ignore_index=True)

res = res.append( {"dataset": "MAG2", "SC": 0.147, "method": "GeoNMF"}, ignore_index=True)
res = res.append( {"dataset": "MAG2", "SC": 0.025, "method": "OCCAM"}, ignore_index=True)
res = res.append( {"dataset": "MAG2", "SC": 0.097, "method": "SAAC"}, ignore_index=True)
# res = res.append( {"dataset": "MAG2", "SC": 0.09, "method": "SVI"}, ignore_index=True)

res.head()
# Out:
#   dataset     SC method
# 0   DBLP5  0.131   SPOC
# 1   DBLP1  0.268   SPOC
# 2   DBLP4  0.333   SPOC
# 3    MAG2  0.161   SPOC
# 4    MAG1  0.035   SPOC

# %%
matplotlib.rc('xtick', labelsize=45) 
matplotlib.rc('ytick', labelsize=45) 
matplotlib.rcParams.update({'font.size': 45})
sns.set(font_scale=2)

plt.figure(figsize=(40,25))

res = res.sort_values(by="dataset")
for num, dataset in enumerate(res.dataset.unique()):
    df = res[res["dataset"] == dataset]
    df = df.sort_values(by="method")
    plt.subplot(2, 4, num+1)
    plt.title(dataset, fontsize = 33)
    sns_hist = sns.barplot(y="SC", x="method", data=df, palette="Blues_d")
    sns_hist.set(xlabel = "", ylabel="")
    sns_hist.tick_params(labelsize = 30)
    
    if num == 0 or num == 4:
        sns_hist.set_ylabel("SC", fontsize=30)
    
plt.savefig("../pictures/hists.png", format = 'png', dpi=1000)
plt.savefig("../pictures/hists.eps", format = 'pdf', dpi=1000)
